# %%
import calculator  # Importing the calculator module

# Using the functions from calculator.py
num1 = 10
num2 = 5

print(f"Addition: {calculator.addition(num1, num2)}")
print(f"Subtraction: {calculator.subtraction(num1, num2)}")
print(f"Multiplication: {calculator.multiplication(num1, num2)}")
print(f"Division: {calculator.division(num1, num2)}")
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
